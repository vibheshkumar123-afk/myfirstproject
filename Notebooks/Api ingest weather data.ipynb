# %%
import requests
import json

response=requests.get('https://wttr.in/Delhi?format=j1')
if response.status_code==200:
    #data=response.json()
    data=response.text
    print("data has been read and saved in to the variable")
else:
   print("Error :",response.status_code) 
#data

# %%
import pandas as pd

df=spark.createDataFrame([data])
df
